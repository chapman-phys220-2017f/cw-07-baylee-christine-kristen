# %% [markdown]
# ## Classwork 7

# %% [markdown]
# ### By Baylee Mumma, Christine Outlaw, Kristen Peet

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import taylor_approx as ta
import array_calculus as ac 
import pandas as pd

# %%
def f1(x):
    return np.tanh(x)

def f2(x):
    return ((x**2)/10 + np.sin(2*x)/2)
def f3(x):

def f4(x): 
    return (1/x)

# %%
#Function 1: tanh
def plots(a=-5,b=5,n=1000):
    x = np.linspace(a,b,n)
    fs = pd.DataFrame({"x": x,"$tanh(x)$": f1(x)})
    fs.plot(x = 'x')
plots()

# %%
#Function 2
def plots(a=-5,b=5,n=1000):
    x = np.linspace(a,b,n)
    fs = pd.DataFrame({"x": x,"$(x^2/10) + (sin(2x)/2)$": f2(x)})
    fs.plot(x = 'x')
plots()
